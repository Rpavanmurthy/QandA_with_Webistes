# %% [markdown]
# #IMPORTS

# %%
from urllib.request import urlopen
import pandas as pd
import numpy as np
from bs4 import BeautifulSoup
import matplotlib.pyplot as plt

# %%
#URLS
url = "http://127.0.0.1:5500/onlytesting/tesing_website.html"

# %%
page = urlopen(url)
html_bytes = page.read()
html = html_bytes.decode("utf-8")

# %%
print(html)
# Out:
# <html>
#     <head>
#         <title>testing</title>
#         <style>
#         form {
#             border: 3px solid #f1f1f1;
#         }
#
#         /* Full-width inputs */
#         input[type=text], input[type=password] {
#             width: 100%;
#             padding: 12px 20px;
#             margin: 8px 0;
#             display: inline-block;
#             border: 1px solid #ccc;
#             box-sizing: border-box;
#         }
#
#         /* Set a style for all buttons */
#         button {
#             background-color: #04AA6D;
#             color: white;
#             padding: 14px 20px;
#             margin: 8px 0;
#             border: none;
#             cursor: pointer;
#             width: 100%;
#         }
#         /* Add a hover effect for buttons */
#         button:hover {
#             opacity: 0.8;
#         }
#         /* Extra style for the cancel button (red) */
#         .cancelbtn {
#             width: auto;
#             padding: 10px 18px;
#             background-color: #f44336;
#         }
#         /* Center the avatar image inside this container */
#         .imgcontainer {
#             text-align: center;
#             margin: 40px 0 30px 0;
#         }
#         /* Avatar image */
#         img.avatar {
#             width: 60%;
#             border-radius: 40%;
#         }
#         /* Add padding to containers */
#         .container {
#             padding: 16px;
#             background-color: black;
#         }
#         /* The "Forgot password" text */
#         span.psw {
#             float: right;
#             padding-top: 16px;
#         }
#         /* Change styles for span and cancel button on extra small screens */
#         @media screen and (max-width: 300px) {
#             span.psw {
#                 display: block;
#                 float: none;
#             }
#             .cancelbtn {
#                 width: 100%;
#             }
#         }
#         </style>
#     </head>
#     <body class="myBody">
#         <form action="action_page.php" method="post">
#             <div class="imgcontainer">
#               <img src="IMG_20240717_142249270.jpg" class="avatar">
#             </div>
#
#             <div class="container">
#               <label style ="color: grey;"for="uname"><b>Username</b></label>
#               <input type="text" placeholder="Enter Username" name="uname" required>
#
#               <label style ="color: grey;"for="psw"><b>Password</b></label>
#               <input type="password" placeholder="Enter Password" name="psw" required>
#
#               <button type="submit">Login</button>
#               <label>
#                 <input type="checkbox" checked="checked" name="remember"> Remember me
#               </label>
#             </div>
#
#             <div class="container" style="background-color:#f1f1f1">
#               <button type="button" class="cancelbtn">Cancel</button>
#               <span class="psw">Forgot <a href="#">password?</a></span>
#             </div>
#           </form>
#     <!-- Code injected by live-server -->
# <script>
# 	// <![CDATA[  <-- For SVG support
# 	if ('WebSocket' in window) {
# 		(function () {
# 			function refreshCSS() {
# 				var sheets = [].slice.call(document.getElementsByTagName("link"));
# 				var head = document.getElementsByTagName("head")[0];
# 				for (var i = 0; i < sheets.length; ++i) {
# 					var elem = sheets[i];
# 					var parent = elem.parentElement || head;
# 					parent.removeChild(elem);
# 					var rel = elem.rel;
# 					if (elem.href && typeof rel != "string" || rel.length == 0 || rel.toLowerCase() == "stylesheet") {
# 						var url = elem.href.replace(/(&|\?)_cacheOverride=\d+/, '');
# 						elem.href = url + (url.indexOf('?') >= 0 ? '&' : '?') + '_cacheOverride=' + (new Date().valueOf());
# 					}
# 					parent.appendChild(elem);
# 				}
# 			}
# 			var protocol = window.location.protocol === 'http:' ? 'ws://' : 'wss://';
# 			var address = protocol + window.location.host + window.location.pathname + '/ws';
# 			var socket = new WebSocket(address);
# 			socket.onmessage = function (msg) {
# 				if (msg.data == 'reload') window.location.reload();
# 				else if (msg.data == 'refreshcss') refreshCSS();
# 			};
# 			if (sessionStorage && !sessionStorage.getItem('IsThisFirstTime_Log_From_LiveServer')) {
# 				console.log('Live reload enabled.');
# 				sessionStorage.setItem('IsThisFirstTime_Log_From_LiveServer', true);
# 			}
# 		})();
# 	}
# 	else {
# 		console.error('Upgrade your browser. This Browser is NOT supported WebSocket for Live-Reloading.');
# 	}
# 	// ]]>
# </script>
# </body>
# </html>

# %%
soup = BeautifulSoup(html,'html.parser')
all_tags = soup.find_all()
for tag in all_tags:
    print(f'TagName : {tag.name}')
    print(f'Attribute : {tag.attrs}')
    print(f'Data : {tag.text}')
    print()
# Out:
# TagName : html
# Attribute : {}
# Data :
#
# testing
#
#
#
#
#
#
#
#
# Username
#
# Password
#
# Login
#
#  Remember me
#
#
#
# Cancel
# Forgot password?
#
#
#
#
#
#
#
# TagName : head
# Attribute : {}
# Data :
# testing
#
#
#
# TagName : title
# Attribute : {}
# Data : testing
#
# TagName : style
# Attribute : {}
# Data :
#         form {
#             border: 3px solid #f1f1f1;
#         }
#
#         /* Full-width inputs */
#         input[type=text], input[type=password] {
#             width: 100%;
#             padding: 12px 20px;
#             margin: 8px 0;
#             display: inline-block;
#             border: 1px solid #ccc;
#             box-sizing: border-box;
#         }
#
#         /* Set a style for all buttons */
#         button {
#             background-color: #04AA6D;
#             color: white;
#             padding: 14px 20px;
#             margin: 8px 0;
#             border: none;
#             cursor: pointer;
#             width: 100%;
#         }
#         /* Add a hover effect for buttons */
#         button:hover {
#             opacity: 0.8;
#         }
#         /* Extra style for the cancel button (red) */
#         .cancelbtn {
#             width: auto;
#             padding: 10px 18px;
#             background-color: #f44336;
#         }
#         /* Center the avatar image inside this container */
#         .imgcontainer {
#             text-align: center;
#             margin: 40px 0 30px 0;
#         }
#         /* Avatar image */
#         img.avatar {
#             width: 60%;
#             border-radius: 40%;
#         }
#         /* Add padding to containers */
#         .container {
#             padding: 16px;
#             background-color: black;
#         }
#         /* The "Forgot password" text */
#         span.psw {
#             float: right;
#             padding-top: 16px;
#         }
#         /* Change styles for span and cancel button on extra small screens */
#         @media screen and (max-width: 300px) {
#             span.psw {
#                 display: block;
#                 float: none;
#             }
#             .cancelbtn {
#                 width: 100%;
#             }
#         }
#
#
# TagName : body
# Attribute : {'class': ['myBody']}
# Data :
#
#
#
#
#
# Username
#
# Password
#
# Login
#
#  Remember me
#
#
#
# Cancel
# Forgot password?
#
#
#
#
#
#
# TagName : form
# Attribute : {'action': 'action_page.php', 'method': 'post'}
# Data :
#
#
#
#
# Username
#
# Password
#
# Login
#
#  Remember me
#
#
#
# Cancel
# Forgot password?
#
#
#
# TagName : div
# Attribute : {'class': ['imgcontainer']}
# Data :
#
#
#
# TagName : img
# Attribute : {'src': 'IMG_20240717_142249270.jpg', 'class': ['avatar']}
# Data :
#
# TagName : div
# Attribute : {'class': ['container']}
# Data :
# Username
#
# Password
#
# Login
#
#  Remember me
#
#
#
# TagName : label
# Attribute : {'style': 'color: grey;', 'for': 'uname'}
# Data : Username
#
# TagName : b
# Attribute : {}
# Data : Username
#
# TagName : input
# Attribute : {'type': 'text', 'placeholder': 'Enter Username', 'name': 'uname', 'required': ''}
# Data :
#
# TagName : label
# Attribute : {'style': 'color: grey;', 'for': 'psw'}
# Data : Password
#
# TagName : b
# Attribute : {}
# Data : Password
#
# TagName : input
# Attribute : {'type': 'password', 'placeholder': 'Enter Password', 'name': 'psw', 'required': ''}
# Data :
#
# TagName : button
# Attribute : {'type': 'submit'}
# Data : Login
#
# TagName : label
# Attribute : {}
# Data :
#  Remember me
#
#
# TagName : input
# Attribute : {'type': 'checkbox', 'checked': 'checked', 'name': 'remember'}
# Data :
#
# TagName : div
# Attribute : {'class': ['container'], 'style': 'background-color:#f1f1f1'}
# Data :
# Cancel
# Forgot password?
#
#
# TagName : button
# Attribute : {'type': 'button', 'class': ['cancelbtn']}
# Data : Cancel
#
# TagName : span
# Attribute : {'class': ['psw']}
# Data : Forgot password?
#
# TagName : a
# Attribute : {'href': '#'}
# Data : password?
#
# TagName : script
# Attribute : {}
# Data :
# 	// <![CDATA[  <-- For SVG support
# 	if ('WebSocket' in window) {
# 		(function () {
# 			function refreshCSS() {
# 				var sheets = [].slice.call(document.getElementsByTagName("link"));
# 				var head = document.getElementsByTagName("head")[0];
# 				for (var i = 0; i < sheets.length; ++i) {
# 					var elem = sheets[i];
# 					var parent = elem.parentElement || head;
# 					parent.removeChild(elem);
# 					var rel = elem.rel;
# 					if (elem.href && typeof rel != "string" || rel.length == 0 || rel.toLowerCase() == "stylesheet") {
# 						var url = elem.href.replace(/(&|\?)_cacheOverride=\d+/, '');
# 						elem.href = url + (url.indexOf('?') >= 0 ? '&' : '?') + '_cacheOverride=' + (new Date().valueOf());
# 					}
# 					parent.appendChild(elem);
# 				}
# 			}
# 			var protocol = window.location.protocol === 'http:' ? 'ws://' : 'wss://';
# 			var address = protocol + window.location.host + window.location.pathname + '/ws';
# 			var socket = new WebSocket(address);
# 			socket.onmessage = function (msg) {
# 				if (msg.data == 'reload') window.location.reload();
# 				else if (msg.data == 'refreshcss') refreshCSS();
# 			};
# 			if (sessionStorage && !sessionStorage.getItem('IsThisFirstTime_Log_From_LiveServer')) {
# 				console.log('Live reload enabled.');
# 				sessionStorage.setItem('IsThisFirstTime_Log_From_LiveServer', true);
# 			}
# 		})();
# 	}
# 	else {
# 		console.error('Upgrade your browser. This Browser is NOT supported WebSocket for Live-Reloading.');
# 	}
# 	// ]]>

# %%
html_info = []
for tag in all_tags:
    row = {
        'Tag' : tag.name,
        'Attribute': tag.attrs,
        'Data' : tag.text
    }
    html_info.append(row)

df = pd.DataFrame(html_info)
print(df)
# Out:
#        Tag                                          Attribute  \
# 0     html                                                 {}
# 1     head                                                 {}
# 2    title                                                 {}
# 3    style                                                 {}
# 4     body                              {'class': ['myBody']}
# 5     form    {'action': 'action_page.php', 'method': 'post'}
# 6      div                        {'class': ['imgcontainer']}
# 7      img  {'src': 'IMG_20240717_142249270.jpg', 'class':...
# 8      div                           {'class': ['container']}
# 9    label          {'style': 'color: grey;', 'for': 'uname'}
# 10       b                                                 {}
# 11   input  {'type': 'text', 'placeholder': 'Enter Usernam...
# 12   label            {'style': 'color: grey;', 'for': 'psw'}
# 13       b                                                 {}
# 14   input  {'type': 'password', 'placeholder': 'Enter Pas...
# 15  button                                 {'type': 'submit'}
# 16   label                                                 {}
# 17   input  {'type': 'checkbox', 'checked': 'checked', 'na...
# 18     div  {'class': ['container'], 'style': 'background-...
# 19  button         {'type': 'button', 'class': ['cancelbtn']}
# 20    span                                 {'class': ['psw']}
# 21       a                                      {'href': '#'}
# 22  script                                                 {}
#
#                                                  Data
# 0   \n\ntesting\n\n\n\n\n\n\n\n\nUsername\n\nPassw...
# 1                                       \ntesting\n\n
# 2                                             testing
# 3   \r\n        form {\r\n            border: 3px ...
# 4   \n\n\n\n\n\nUsername\n\nPassword\n\nLogin\n\n ...
# 5   \n\n\n\n\nUsername\n\nPassword\n\nLogin\n\n Re...
# 6                                                \n\n
# 7
# 8   \nUsername\n\nPassword\n\nLogin\n\n Remember m...
# 9                                            Username
# 10                                           Username
# 11
# 12                                           Password
# 13                                           Password
# 14
# 15                                              Login
# 16                   \n Remember me\r\n
# 17
# 18                       \nCancel\nForgot password?\n
# 19                                             Cancel
# 20                                   Forgot password?
# 21                                          password?
# 22  \n\t// <![CDATA[  <-- For SVG support\n\tif ('...

# %%
df_1 = pd.DataFrame(html_info)

# %%
input_df = df[df['Tag']=='input']
input_df
# Out:
#       Tag                                          Attribute Data
# 11  input  {'type': 'text', 'placeholder': 'Enter Usernam...
# 14  input  {'type': 'password', 'placeholder': 'Enter Pas...
# 17  input  {'type': 'checkbox', 'checked': 'checked', 'na...

# %%
xdf = df[df["Attribute"]!="{'href': '#'}"]
xdf
# Out:
# Empty DataFrame
# Columns: [Tag, Attribute, Data]
# Index: []
