# %% [markdown]
# #IMPORTS

# %%
from urllib.request import urlopen
import pandas as pd
import numpy as np
from bs4 import BeautifulSoup
import matplotlib.pyplot as plt

# %%
#URLS
url = "http://127.0.0.1:5500/onlytesting/tesing_website.html"

# %%
page = urlopen(url)
html_bytes = page.read()
html = html_bytes.decode("utf-8")

# %%
print(html)
# Out:
# <html>
#     <head>
#         <title>testing</title>
#         <style>
#             .myDiv{
#                 background-color: grey;
#                 align-content: center;
#                 padding-left: 800px;
#                 padding-right: 800px;
#                 padding-top: 350px;
#                 padding-bottom: 350px;
#                 border-radius: 10px;
#
#             }
#             .myBody{
#                 background-color: grey;
#             }
#             form {
#   border: 3px solid #f1f1f1;
# }
#
# /* Full-width inputs */
# input[type=text], input[type=password] {
#   width: 100%;
#   padding: 12px 20px;
#   margin: 8px 0;
#   display: inline-block;
#   border: 1px solid #ccc;
#   box-sizing: border-box;
# }
#
# /* Set a style for all buttons */
# button {
#   background-color: #04AA6D;
#   color: white;
#   padding: 14px 20px;
#   margin: 8px 0;
#   border: none;
#   cursor: pointer;
#   width: 100%;
# }
#
# /* Add a hover effect for buttons */
# button:hover {
#   opacity: 0.8;
# }
#
# /* Extra style for the cancel button (red) */
# .cancelbtn {
#   width: auto;
#   padding: 10px 18px;
#   background-color: #f44336;
# }
#
# /* Center the avatar image inside this container */
# .imgcontainer {
#   text-align: center;
#   margin: 24px 0 12px 0;
# }
#
# /* Avatar image */
# img.avatar {
#   width: 40%;
#   border-radius: 50%;
# }
#
# /* Add padding to containers */
# .container {
#   padding: 16px;
# }
#
# /* The "Forgot password" text */
# span.psw {
#   float: right;
#   padding-top: 16px;
# }
#
# /* Change styles for span and cancel button on extra small screens */
# @media screen and (max-width: 300px) {
#   span.psw {
#     display: block;
#     float: none;
#   }
#   .cancelbtn {
#     width: 100%;
#   }
# }
#         </style>
#     </head>
#     <body class="myBody">
#         <form action="action_page.php" method="post">
#             <div class="imgcontainer">
#               <img src="img_avatar2.png" alt="Avatar" class="avatar">
#             </div>
#
#             <div class="container">
#               <label for="uname"><b>Username</b></label>
#               <input type="text" placeholder="Enter Username" name="uname" required>
#
#               <label for="psw"><b>Password</b></label>
#               <input type="password" placeholder="Enter Password" name="psw" required>
#
#               <button type="submit">Login</button>
#               <label>
#                 <input type="checkbox" checked="checked" name="remember"> Remember me
#               </label>
#             </div>
#
#             <div class="container" style="background-color:#f1f1f1">
#               <button type="button" class="cancelbtn">Cancel</button>
#               <span class="psw">Forgot <a href="#">password?</a></span>
#             </div>
#           </form>
#     <!-- Code injected by live-server -->
# <script>
# 	// <![CDATA[  <-- For SVG support
# 	if ('WebSocket' in window) {
# 		(function () {
# 			function refreshCSS() {
# 				var sheets = [].slice.call(document.getElementsByTagName("link"));
# 				var head = document.getElementsByTagName("head")[0];
# 				for (var i = 0; i < sheets.length; ++i) {
# 					var elem = sheets[i];
# 					var parent = elem.parentElement || head;
# 					parent.removeChild(elem);
# 					var rel = elem.rel;
# 					if (elem.href && typeof rel != "string" || rel.length == 0 || rel.toLowerCase() == "stylesheet") {
# 						var url = elem.href.replace(/(&|\?)_cacheOverride=\d+/, '');
# 						elem.href = url + (url.indexOf('?') >= 0 ? '&' : '?') + '_cacheOverride=' + (new Date().valueOf());
# 					}
# 					parent.appendChild(elem);
# 				}
# 			}
# 			var protocol = window.location.protocol === 'http:' ? 'ws://' : 'wss://';
# 			var address = protocol + window.location.host + window.location.pathname + '/ws';
# 			var socket = new WebSocket(address);
# 			socket.onmessage = function (msg) {
# 				if (msg.data == 'reload') window.location.reload();
# 				else if (msg.data == 'refreshcss') refreshCSS();
# 			};
# 			if (sessionStorage && !sessionStorage.getItem('IsThisFirstTime_Log_From_LiveServer')) {
# 				console.log('Live reload enabled.');
# 				sessionStorage.setItem('IsThisFirstTime_Log_From_LiveServer', true);
# 			}
# 		})();
# 	}
# 	else {
# 		console.error('Upgrade your browser. This Browser is NOT supported WebSocket for Live-Reloading.');
# 	}
# 	// ]]>
# </script>
# </body>
# </html>

# %%
soup = BeautifulSoup(html,'html.parser')
all_tags = soup.find_all()
for tag in all_tags:
    print(f'TagName : {tag.name}')
    print()
    print(f'Attribute : {tag.attrs}')
    print()
    print(f'Data : {tag.text}')
# Out:
# TagName : html
#
# Attribute : {}
#
# Data :
#
# testing
#
#
#
#
#
#
#
#
# Username
#
# Password
#
# Login
#
#  Remember me
#
#
#
# Cancel
# Forgot password?
#
#
#
#
#
#
# TagName : head
#
# Attribute : {}
#
# Data :
# testing
#
#
# TagName : title
#
# Attribute : {}
#
# Data : testing
# TagName : style
#
# Attribute : {}
#
# Data :
#             .myDiv{
#                 background-color: grey;
#                 align-content: center;
#                 padding-left: 800px;
#                 padding-right: 800px;
#                 padding-top: 350px;
#                 padding-bottom: 350px;
#                 border-radius: 10px;
#
#             }
#             .myBody{
#                 background-color: grey;
#             }
#             form {
#   border: 3px solid #f1f1f1;
# }
#
# /* Full-width inputs */
# input[type=text], input[type=password] {
#   width: 100%;
#   padding: 12px 20px;
#   margin: 8px 0;
#   display: inline-block;
#   border: 1px solid #ccc;
#   box-sizing: border-box;
# }
#
# /* Set a style for all buttons */
# button {
#   background-color: #04AA6D;
#   color: white;
#   padding: 14px 20px;
#   margin: 8px 0;
#   border: none;
#   cursor: pointer;
#   width: 100%;
# }
#
# /* Add a hover effect for buttons */
# button:hover {
#   opacity: 0.8;
# }
#
# /* Extra style for the cancel button (red) */
# .cancelbtn {
#   width: auto;
#   padding: 10px 18px;
#   background-color: #f44336;
# }
#
# /* Center the avatar image inside this container */
# .imgcontainer {
#   text-align: center;
#   margin: 24px 0 12px 0;
# }
#
# /* Avatar image */
# img.avatar {
#   width: 40%;
#   border-radius: 50%;
# }
#
# /* Add padding to containers */
# .container {
#   padding: 16px;
# }
#
# /* The "Forgot password" text */
# span.psw {
#   float: right;
#   padding-top: 16px;
# }
#
# /* Change styles for span and cancel button on extra small screens */
# @media screen and (max-width: 300px) {
#   span.psw {
#     display: block;
#     float: none;
#   }
#   .cancelbtn {
#     width: 100%;
#   }
# }
#
# TagName : body
#
# Attribute : {'class': ['myBody']}
#
# Data :
#
#
#
#
#
# Username
#
# Password
#
# Login
#
#  Remember me
#
#
#
# Cancel
# Forgot password?
#
#
#
#
#
# TagName : form
#
# Attribute : {'action': 'action_page.php', 'method': 'post'}
#
# Data :
#
#
#
#
# Username
#
# Password
#
# Login
#
#  Remember me
#
#
#
# Cancel
# Forgot password?
#
#
# TagName : div
#
# Attribute : {'class': ['imgcontainer']}
#
# Data :
#
#
# TagName : img
#
# Attribute : {'src': 'img_avatar2.png', 'alt': 'Avatar', 'class': ['avatar']}
#
# Data :
# TagName : div
#
# Attribute : {'class': ['container']}
#
# Data :
# Username
#
# Password
#
# Login
#
#  Remember me
#
#
# TagName : label
#
# Attribute : {'for': 'uname'}
#
# Data : Username
# TagName : b
#
# Attribute : {}
#
# Data : Username
# TagName : input
#
# Attribute : {'type': 'text', 'placeholder': 'Enter Username', 'name': 'uname', 'required': ''}
#
# Data :
# TagName : label
#
# Attribute : {'for': 'psw'}
#
# Data : Password
# TagName : b
#
# Attribute : {}
#
# Data : Password
# TagName : input
#
# Attribute : {'type': 'password', 'placeholder': 'Enter Password', 'name': 'psw', 'required': ''}
#
# Data :
# TagName : button
#
# Attribute : {'type': 'submit'}
#
# Data : Login
# TagName : label
#
# Attribute : {}
#
# Data :
#  Remember me
#
# TagName : input
#
# Attribute : {'type': 'checkbox', 'checked': 'checked', 'name': 'remember'}
#
# Data :
# TagName : div
#
# Attribute : {'class': ['container'], 'style': 'background-color:#f1f1f1'}
#
# Data :
# Cancel
# Forgot password?
#
# TagName : button
#
# Attribute : {'type': 'button', 'class': ['cancelbtn']}
#
# Data : Cancel
# TagName : span
#
# Attribute : {'class': ['psw']}
#
# Data : Forgot password?
# TagName : a
#
# Attribute : {'href': '#'}
#
# Data : password?
# TagName : script
#
# Attribute : {}
#
# Data :
# 	// <![CDATA[  <-- For SVG support
# 	if ('WebSocket' in window) {
# 		(function () {
# 			function refreshCSS() {
# 				var sheets = [].slice.call(document.getElementsByTagName("link"));
# 				var head = document.getElementsByTagName("head")[0];
# 				for (var i = 0; i < sheets.length; ++i) {
# 					var elem = sheets[i];
# 					var parent = elem.parentElement || head;
# 					parent.removeChild(elem);
# 					var rel = elem.rel;
# 					if (elem.href && typeof rel != "string" || rel.length == 0 || rel.toLowerCase() == "stylesheet") {
# 						var url = elem.href.replace(/(&|\?)_cacheOverride=\d+/, '');
# 						elem.href = url + (url.indexOf('?') >= 0 ? '&' : '?') + '_cacheOverride=' + (new Date().valueOf());
# 					}
# 					parent.appendChild(elem);
# 				}
# 			}
# 			var protocol = window.location.protocol === 'http:' ? 'ws://' : 'wss://';
# 			var address = protocol + window.location.host + window.location.pathname + '/ws';
# 			var socket = new WebSocket(address);
# 			socket.onmessage = function (msg) {
# 				if (msg.data == 'reload') window.location.reload();
# 				else if (msg.data == 'refreshcss') refreshCSS();
# 			};
# 			if (sessionStorage && !sessionStorage.getItem('IsThisFirstTime_Log_From_LiveServer')) {
# 				console.log('Live reload enabled.');
# 				sessionStorage.setItem('IsThisFirstTime_Log_From_LiveServer', true);
# 			}
# 		})();
# 	}
# 	else {
# 		console.error('Upgrade your browser. This Browser is NOT supported WebSocket for Live-Reloading.');
# 	}
# 	// ]]>
