# %% [markdown]
# #IMPORTS

# %%
from urllib.request import urlopen
import pandas as pd
import numpy as np
from bs4 import BeautifulSoup
import matplotlib.pyplot as plt
import webbrowser

# %%
#URLS
url = "http://127.0.0.1:5500/onlytesting/tesing_website.html#"

# %%
page = urlopen(url)
html_bytes = page.read()
html = html_bytes.decode("utf-8")

# %%
print(html)
# Out:
# <html>
#     <head>
#         <title>testing</title>
#         <style>
#         form {
#             border: 3px solid #f1f1f1;
#         }
#
#         /* Full-width inputs */
#         input[type=text], input[type=password] {
#             width: 100%;
#             padding: 12px 20px;
#             margin: 8px 0;
#             display: inline-block;
#             border: 1px solid #ccc;
#             box-sizing: border-box;
#         }
#
#         /* Set a style for all buttons */
#         button {
#             background-color: #0b9c1e;
#             color: white;
#             padding: 14px 20px;
#             margin: 8px 0;
#             border: none;
#             cursor: pointer;
#             width: 30%;
#
#         }
#         /* Add a hover effect for buttons */
#         button:hover {
#             opacity: 0.7;
#         }
#         /* Extra style for the cancel button (red) */
#         .cancelbtn {
#             width: auto;
#             padding: 10px 18px;
# ...

# %%
soup = BeautifulSoup(html,'html.parser')
all_tags = soup.find_all()
for tag in all_tags:
    print(f'TagName : {tag.name}')
    print(f'Attribute : {tag.attrs}')
    print(f'Data : {tag.text}')
    print()

# %%
html_info = []
for tag in all_tags:
    row = {
        'Tag' : tag.name,
        'Attribute': tag.attrs,
        'Data' : tag.text
    }
    html_info.append(row)

df = pd.DataFrame(html_info)
print(df)
# Out:
#        Tag                                          Attribute  \
# 0     html                                                 {}
# 1     head                                                 {}
# 2    title                                                 {}
# 3    style                                                 {}
# 4     body                              {'class': ['myBody']}
# 5     form    {'action': 'action_page.php', 'method': 'post'}
# 6      div                           {'class': ['container']}
# 7      img  {'src': 'IMG_20240717_142249270.jpg', 'alt': '...
# 8      div                           {'class': ['centering']}
# 9      div                           {'class': ['container']}
# 10   label         {'style': 'color: black;', 'for': 'uname'}
# 11       b                                                 {}
# 12   input  {'type': 'text', 'placeholder': 'Enter Usernam...
# 13   label           {'style': 'color: black;', 'for': 'psw'}
# ...

# %%
df_1 = pd.DataFrame(html_info)

# %%
input_df = df_1[df_1['Tag']=='input']
input_df
# Out:
#       Tag                                          Attribute Data
# 12  input  {'type': 'text', 'placeholder': 'Enter Usernam...
# 15  input  {'type': 'password', 'placeholder': 'Enter Pas...
# 19  input  {'type': 'checkbox', 'checked': 'checked', 'na...

# %%
e = input_df.iloc[1,1]
for i,j in e.items():
    if i == "type" and j == "password":
        webbrowser.open("http://127.0.0.1:5500/onlytesting/tesing_website.html#")
